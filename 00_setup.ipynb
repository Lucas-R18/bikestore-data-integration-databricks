# %%
# %sql
-- cria catálogo do projeto
create catalog if not exists c_bikeshop;

# %%
# %sql
create schema if not exists c_bikeshop.raw;

# %%
# %sql
create schema if not exists c_bikeshop.bronze;
create schema if not exists c_bikeshop.silver;
create schema if not exists c_bikeshop.gold;

# %%
# %sql
create volume if not exists c_bikeshop.raw.raw_files

# %%
# %sql 
-- show volumes in c_bikeshop.raw
